# %%
import pandas as pd

# %%
species = pd.read_csv("~/Documents/DataCarpentry/species.csv")

# %%
species.head()
# Out:
#   species_id             genus          species    taxa
# 0         AB        Amphispiza        bilineata    Bird
# 1         AH  Ammospermophilus          harrisi  Rodent
# 2         AS        Ammodramus       savannarum    Bird
# 3         BA           Baiomys          taylori  Rodent
# 4         CB   Campylorhynchus  brunneicapillus    Bird

# %%
surveys = pd.read_csv("~/Documents/DataCarpentry/surveys.csv")

# %%
surveys.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
merged = pd.merge(species, surveys,left_on = 'species_id', right_on = 'species_id')

# %%
merged.head()
# Out:
#   species_id       genus    species  taxa  record_id  month  day  year  \
# 0         AB  Amphispiza  bilineata  Bird       3126      7   21  1980
# 1         AB  Amphispiza  bilineata  Bird       3146      7   21  1980
# 2         AB  Amphispiza  bilineata  Bird       3152      7   21  1980
# 3         AB  Amphispiza  bilineata  Bird       3153      7   21  1980
# 4         AB  Amphispiza  bilineata  Bird       3586     12   15  1980
#
#    plot_id  sex  hindfoot_length  weight
# 0        8  NaN              NaN     NaN
# 1       24  NaN              NaN     NaN
# 2       19  NaN              NaN     NaN
# 3       22  NaN              NaN     NaN
# 4       16  NaN              NaN     NaN
